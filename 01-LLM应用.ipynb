# %%
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
import os

load_dotenv(override=True)
api_key = os.getenv("OPENAI_API_KEY")
os.environ["openai_api_key"] = api_key

# %%
chat = ChatOpenAI(
    model="gpt-4o-mini",
    temperature=0.5,  #模型温度，0-1之间，值越小，随机性越低
)
chat.invoke("夏天适合吃什么水果？")
# Out:
# AIMessage(content='夏天适合吃的水果有很多，主要是因为这些水果水分丰富，能够帮助解暑和补充身体所需的水分。以下是一些适合夏天吃的水果：\n\n1. **西瓜**：含水量高，清凉解暑，是夏天的经典水果。\n2. **黄瓜**：虽然是蔬菜，但常被当作水果食用，清爽可口，适合夏天。\n3. **桃子**：多汁甜美，能够提供丰富的维生素和水分。\n4. **葡萄**：水分充足，口感甜美，适合冷藏后食用。\n5. **菠萝**：酸甜可口，富含维生素C，能够帮助消化。\n6. **草莓**：虽然是春季水果，但夏天仍然可以找到，清爽可口。\n7. **荔枝**：甜美多汁，适合夏季食用，但要适量。\n8. **樱桃**：营养丰富，口感好，适合在夏季享用。\n9. **椰子**：椰子水清凉解渴，非常适合炎热的夏季。\n\n总之，夏天可以选择一些水分丰富、清爽的水果来消暑，保持身体的水分平衡。', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 298, 'prompt_tokens': 15, 'total_tokens': 313, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_0950b7f384', 'id': 'chatcmpl-EEwHMBpAeabRFqhVNBuGw6P8ywxh3', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a01f2b-3de9-7913-9e59-d5cbd74d59b9-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 15, 'output_tokens': 298, 'total_tokens': 313, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage, SystemMessage, AIMessage
import os

os.environ["openai_api_key"] = api_key

chat = ChatOpenAI(
    model="gpt-4o-mini",
    temperature=0.5,  #模型温度，0-1之间，值越小，随机性越低
)
messages = [
    SystemMessage(content='Your role is poet.'),
    AIMessage(content='Hi.'),
    HumanMessage(content='Write a short poem about AI in four lines.'),
]
response = chat.invoke(messages)

print(response.content)
# Out:
# In circuits hums a thought divine,
# A spark of code, a crafted line.
# With every query, wisdom grows,
# In silent depths, the future flows.

# %%
from langchain_ollama.llms import OllamaLLM

model = OllamaLLM(model="deepseek-r1:1.5b")

response = model.invoke("夏天适合吃什么水果？")

print(response)
# Out:
# 夏天适合吃的水果有很多，它们酸甜，容易保存，颜色鲜艳，或者可以直接作为零食，适合凉拌或者直接食用。以下是一些适合夏天吃的水果：
#
# 1. **苹果**：酸甜的口感，夏天很受欢迎。
# 2. **西瓜**：颜色鲜艳，味道甜，夏天很多人喜欢吃西瓜。
# 3. **橙子**：甜的口感，适合凉拌或直接食用。
# 4. **柠檬**：酸甜，容易保存，夏天适合用饮料。
# 5. **葡萄**：果实大，颜色鲜艳，可以和苹果一起吃。
# 6. **柿子**：颜色鲜艳，有果香，夏天可以吃。
# 7. **香蕉**：酸甜，适合凉拌或直接食用。
# 8. **芒果**：有酸甜的口感，夏天可以凉拌或直接食用。
# 9. **苹果汁**：直接用苹果汁做的，汁液清澈，夏天可以冰镇或饮用。
# 10. **果汁**：可以用来制作蛋糕、饮料，夏天可以凉拌或直接饮用。
# 11. **葡萄汁**：直接用葡萄汁做的，夏天可以凉拌或直接饮用。
# 12. **香蕉汁**：适合凉拌或直接饮用。
# 13. **柠檬汁**：适合凉拌或直接饮用。
#
# 如果你有特别的需求，比如需要凉拌，可以考虑这些水果的切片或粉末，适合配菜。
