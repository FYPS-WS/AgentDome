# %%
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv

load_dotenv(override=True)

chat = ChatOpenAI(
    model="gpt-4o-mini",
    temperature=0,
)

# %% [markdown]
# ### Conversation Buffer Memory

# %%
from langchain_classic.memory import ConversationBufferMemory
from langchain_classic import ConversationChain
from langchain.agents import create_agent

# create a memory system
memory = ConversationBufferMemory()

# create a session chain
conversation = ConversationChain(llm = chat, memory = memory)

# %%
conversation.predict(input = "你好, 我是一个程序员")
# Out:
# '你好！很高兴认识你，程序员！你在做什么类型的编程呢？是前端、后端，还是全栈开发？或者你在使用某种特定的编程语言吗？我很乐意聊聊编程相关的话题！'

# %%
conversation.predict(input="你叫什么名字")
# Out:
# '我没有一个特定的名字，但你可以叫我AI助手或者任何你喜欢的名字！我在这里帮助你解答问题和进行有趣的对话。你有什么想聊的或者想问我的呢？'

# %%
conversation.predict(input="我的职业是什么")
# Out:
# '你刚刚提到你是一个程序员，所以你的职业就是程序员！你在编程方面一定有很多有趣的经历和项目。如果你愿意，可以分享一下你最近在做的项目或者你最喜欢的编程语言！'

# %% [markdown]
# ### ConversationBufferWindowsMemory

# %%
from langchain_classic.memory import ConversationBufferWindowMemory
from langchain_classic.chains import ConversationChain

memory = ConversationBufferWindowMemory(k = 2)
conversation = ConversationChain(llm = chat,memory = memory)

# %%
conversation.predict(input = "你好, 我是一个程序员")
# Out:
# '你好！很高兴认识你，程序员！你在做什么样的项目呢？使用什么编程语言？我很乐意聊聊编程相关的话题！'

# %%
conversation.predict(input = "我的名字叫齐天大圣")
# Out:
# '很高兴认识你，齐天大圣！这个名字让我想起了《西游记》中的孙悟空，他可是个非常厉害的角色呢！你在编程方面有没有什么特别的兴趣或者项目？或者你喜欢用什么样的技术栈呢？'

# %%
conversation.predict(input = "我的职业是什么？")
# Out:
# '你刚才提到你是一个程序员，所以你的职业就是程序员！你在这个领域工作多久了？有没有特别喜欢的编程语言或框架？'

# %% [markdown]
# ### 查看记忆系统

# %%
# 提取记忆
print(memory.buffer)
# Out:
# Human: 我的名字叫齐天大圣
# AI: 很高兴认识你，齐天大圣！这个名字让我想起了《西游记》中的孙悟空，他可是个非常厉害的角色呢！你在编程方面有没有什么特别的兴趣或者项目？或者你喜欢用什么样的技术栈呢？
# Human: 我的职业是什么？
# AI: 你刚才提到你是一个程序员，所以你的职业就是程序员！你在这个领域工作多久了？有没有特别喜欢的编程语言或框架？

# %%
print(memory.load_memory_variables({}))
# Out:
# {'history': 'Human: 我的名字叫齐天大圣\nAI: 很高兴认识你，齐天大圣！这个名字让我想起了《西游记》中的孙悟空，他可是个非常厉害的角色呢！你在编程方面有没有什么特别的兴趣或者项目？或者你喜欢用什么样的技术栈呢？\nHuman: 我的职业是什么？\nAI: 你刚才提到你是一个程序员，所以你的职业就是程序员！你在这个领域工作多久了？有没有特别喜欢的编程语言或框架？'}

# %%
#追加上下文
memory.save_context({"input":"Hi"},{"output":"what's up"})
memory.chat_memory.add_user_message("你好")
memory.chat_memory.add_ai_message("您好")
memory.save_context({"input":"Hi"},{"output":"what's up"})

# %%
print(memory.buffer)
# Out:
# Human: 你好
# AI: 您好
# Human: Hi
# AI: what's up

# %%
from langchain_classic.memory import ConversationTokenBufferMemory
from langchain_classic.chains import ConversationChain
from langchain_openai import OpenAI

memory = ConversationTokenBufferMemory(llm = chat, max_token_limit=100)

memory.save_context({"input": "您好！"},{"output":"你好有什么可以帮助您的？"})
memory.save_context({"input": "我喜欢编程"},{"output":"太棒了！您喜欢用哪种编程语言？"})
memory.save_context({"input": "python是我的最爱"},{"output":"python很强大！您用它做什么项目"})
memory.save_context({"input": "我在做一个聊天机器人"},{"output":"cool！像我这样的吗"})

conversation = ConversationChain(llm = chat, memory = memory)

# %%
print(memory.buffer)
# Out:
# Human: 我是一名程序员，喜欢用python
# AI: 太棒了，小明！Python是一种非常灵活的编程语言，适合各种项目。你在编写聊天机器人时使用了哪些库或框架呢？比如说，你可能会用到像NLTK、spaCy或者是更流行的框架如ChatterBot或Rasa。你有没有特别喜欢的库？

# %%
print(memory.load_memory_variables({}))
# Out:
# {'history': 'Human: 我在做一个聊天机器人\nAI: cool！像我这样的吗'}

# %%
conversation.predict(input = "你好我的名字叫小明 ")
# Out:
# '你好，小明！很高兴认识你！你在聊天机器人项目中使用了哪些功能或技术呢？'

# %%
conversation.predict(input = "我是一名程序员，喜欢用python ")
# Out:
# '太棒了，小明！Python是一种非常灵活的编程语言，适合各种项目。你在编写聊天机器人时使用了哪些库或框架呢？比如说，你可能会用到像NLTK、spaCy或者是更流行的框架如ChatterBot或Rasa。你有没有特别喜欢的库？'

# %%
conversation.predict(input = "你还记得我的名字吗？ ")
# Out:
# '当然记得！你叫小明。很高兴和你聊天！如果你有任何关于Python编程的问题或者想分享你的项目，随时告诉我！'

# %%
conversation.predict(input = "我的职业是什么？ ")
# Out:
# '抱歉，我不知道你的职业是什么。如果你愿意，可以告诉我，我很乐意了解更多关于你的工作和兴趣！'
